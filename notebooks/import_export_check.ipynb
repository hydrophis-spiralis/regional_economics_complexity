# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('../data/raw/year_origin_destination_hs07_4.tsv', sep='\t')

# %%
data=  data[data.year==2016]

# %%
left_data = data[data.hs07 == 2001]
right_data = data[data.hs07 == 2001].copy()

# %%
merged = pd.merge(left_data, right_data, left_on=[left_data.origin, left_data.dest, left_data.hs07], right_on=[right_data.dest, right_data.origin, right_data.hs07])

# %%
merged[merged.export_val_x != merged.import_val_y][['export_val_x', 'import_val_y']]
# Out:
#       export_val_x  import_val_y
# 0              NaN           NaN
# 1              NaN           NaN
# 2              NaN           NaN
# 3              NaN           NaN
# 4              NaN           NaN
# 5              NaN           NaN
# 6              NaN           NaN
# 7              NaN           NaN
# 8              NaN           NaN
# 9              NaN           NaN
# 10             NaN           NaN
# 11             NaN           NaN
# 12             NaN           NaN
# 13             NaN           NaN
# 14             NaN           NaN
# 15             NaN           NaN
# 16             NaN           NaN
# 17             NaN           NaN
# 18             NaN           NaN
# 19             NaN           NaN
# 20             NaN           NaN
# 21             NaN           NaN
# 22             NaN           NaN
# 23             NaN           NaN
# 24             NaN           NaN
# 25             NaN           NaN
# 26             NaN           NaN
# ...

# %%
merged.columns
# Out:
# Index(['key_0', 'key_1', 'key_2', 'year_x', 'origin_x', 'dest_x', 'hs07_x',
#        'export_val_x', 'import_val_x', 'year_y', 'origin_y', 'dest_y',
#        'hs07_y', 'export_val_y', 'import_val_y'],
#       dtype='object')

# %%
merged.drop(['key_0', 'key_1', 'year_x', 'year_y'], axis=1, inplace=True)

# %%
merged.drop(['key_2'], axis=1, inplace=True)
merged.columns
# Out:
# Index(['origin_x', 'dest_x', 'hs07_x', 'export_val_x', 'import_val_x',
#        'origin_y', 'dest_y', 'hs07_y', 'export_val_y', 'import_val_y'],
#       dtype='object')

# %%
merged[merged.import_val_x != merged.export_val_y]
# Out:
#      origin_x dest_x  hs07_x  export_val_x  import_val_x origin_y dest_y  \
# 27        civ    blx    2001       2707.74           NaN      blx    civ
# 57        dza    ner    2001       2804.39           NaN      ner    dza
# 61        dza    kwt    2001       1514.06           NaN      kwt    dza
# 69        dza    can    2001       1233.76           NaN      can    dza
# 71        egy    dza    2001     964385.60           NaN      dza    egy
# 72        egy    eth    2001       2788.87           NaN      eth    egy
# 73        egy    ken    2001      45909.00           NaN      ken    egy
# 74        egy    lby    2001    3195248.00           NaN      lby    egy
# 75        egy    mar    2001      40789.00           NaN      mar    egy
# 76        egy    sdn    2001      14187.00           NaN      sdn    egy
# 77        egy    syc    2001      18938.00           NaN      syc    egy
# 78        egy    tun    2001      76989.81           NaN      tun    egy
# ...
